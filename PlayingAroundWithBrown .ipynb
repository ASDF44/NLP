# %%
# import the brown corpus which consists of novels
from nltk.corpus import brown

# %%
# get all the genres of books in the corpus
brown.categories()
# Out:
# ['adventure',
#  'belles_lettres',
#  'editorial',
#  'fiction',
#  'government',
#  'hobbies',
#  'humor',
#  'learned',
#  'lore',
#  'mystery',
#  'news',
#  'religion',
#  'reviews',
#  'romance',
#  'science_fiction']

# %%
# Get the total number of words in the genre adventure in the brown corpus
len(brown.words(categories = ['adventure']))
# Out:
# 69342

# %%
# Get the first 100 words from adventure genre in the brown corpus
brown.words(categories = ['adventure'])[:100]
# Out:
# ['Dan', 'Morgan', 'told', 'himself', 'he', 'would', ...]

# %%
# Import the inaugural corpus which consists of speeches of US Presidents
from nltk.corpus import inaugural

# %%
# Get the list of all the president' speeches
inaugural.fileids()
# Out:
# ['1789-Washington.txt',
#  '1793-Washington.txt',
#  '1797-Adams.txt',
#  '1801-Jefferson.txt',
#  '1805-Jefferson.txt',
#  '1809-Madison.txt',
#  '1813-Madison.txt',
#  '1817-Monroe.txt',
#  '1821-Monroe.txt',
#  '1825-Adams.txt',
#  '1829-Jackson.txt',
#  '1833-Jackson.txt',
#  '1837-VanBuren.txt',
#  '1841-Harrison.txt',
#  '1845-Polk.txt',
#  '1849-Taylor.txt',
#  '1853-Pierce.txt',
#  '1857-Buchanan.txt',
#  '1861-Lincoln.txt',
#  '1865-Lincoln.txt',
#  '1869-Grant.txt',
#  '1873-Grant.txt',
#  '1877-Hayes.txt',
#  '1881-Garfield.txt',
#  '1885-Cleveland.txt',
#  '1889-Harrison.txt',
#  '1893-Cleveland.txt',
#  '1897-McKinley.txt',
#  '1901-McKinley.txt',
#  '1905-Roosevelt.txt',
#  '1909-Taft.txt',
#  '1913-Wilson.txt',
#  '1917-Wilson.txt',
#  '1921-Harding.txt',
#  '1925-Coolidge.txt',
#  '1929-Hoover.txt',
#  '1933-Roosevelt.txt',
#  '1937-Roosevelt.txt',
#  '1941-Roosevelt.txt',
#  '1945-Roosevelt.txt',
#  '1949-Truman.txt',
#  '1953-Eisenhower.txt',
#  '1957-Eisenhower.txt',
#  '1961-Kennedy.txt',
#  '1965-Johnson.txt',
#  '1969-Nixon.txt',
#  '1973-Nixon.txt',
#  '1977-Carter.txt',
#  '1981-Reagan.txt',
#  '1985-Reagan.txt',
#  '1989-Bush.txt',
#  '1993-Clinton.txt',
#  '1997-Clinton.txt',
#  '2001-Bush.txt',
#  '2005-Bush.txt',
#  '2009-Obama.txt',
#  '2013-Obama.txt',
#  '2017-Trump.txt']

# %%
# Get the total number of speeches in the corpus
len(inaugural.fileids())
# Out:
# 58

# %%
# Get the words in Trump's speech
inaugural.words(fileids=['2017-Trump.txt'])
# Out:
# ['Chief', 'Justice', 'Roberts', ',', 'President', ...]

# %%
# Get the total number of words from Trump's speech i.e. how much he bored the crowd
len(inaugural.words(fileids=['2017-Trump.txt']))
# Out:
# 1693

# %%
# Get all the speeches of Abraham Lincoln
inaugural.words(fileids=['1861-Lincoln.txt','1865-Lincoln.txt'])
# Out:
# ['Fellow', '-', 'Citizens', 'of', 'the', 'United', ...]

# %%
# Get the first 20 words in Lincoln's speech
inaugural.words(fileids=['1861-Lincoln.txt'])[:20]
# Out:
# ['Fellow',
#  '-',
#  'Citizens',
#  'of',
#  'the',
#  'United',
#  'States',
#  ':',
#  'In',
#  'compliance',
#  'with',
#  'a',
#  'custom',
#  'as',
#  'old',
#  'as',
#  'the',
#  'Government',
#  'itself',
#  ',']

# %%
# Get the first term speech of Obama
inaugural.words(fileids=['2009-Obama.txt'])[:5]
# Out:
# ['My', 'fellow', 'citizens', ':', 'I']

# %%
# import everything from nltk.book library i.e. the corpus of novels
from nltk.book import *

# %%
# Get the frequemcy distribution of all the characters in the novel- Moby Dick
f = FreqDist(text1)
f
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
# Get the number of distinct characters in the novel Moby Dick
len(f)
# Out:
# 19317

# %%
# Get the first 10 most common characters
f.most_common()[:10]
# Out:
# [(',', 18713),
#  ('the', 13721),
#  ('.', 6862),
#  ('of', 6536),
#  ('and', 6024),
#  ('a', 4569),
#  ('to', 4542),
#  (';', 4072),
#  ('in', 3916),
#  ('that', 2982)]

# %%
# Get the first term speech of Jimmy Carter
i = inaugural.words(fileids=['1977-Carter.txt'])
i
# Out:
# ['For', 'myself', 'and', 'for', 'our', 'Nation', ',', ...]

# %%
# Get the frequemcy distribution of Carter's speech
f = FreqDist(i)
f
# Out:
# FreqDist({',': 65, '.': 50, 'the': 49, 'and': 45, 'to': 43, 'of': 33, 'our': 31, 'a': 28, 'we': 27, 'for': 23, ...})

# %%
# Find the first 5 most common words in Carter's speech
f.most_common(5)
# Out:
# [(',', 65), ('.', 50), ('the', 49), ('and', 45), ('to', 43)]

# %%
# Find the first 10 most common words in Carter's speech
f.most_common(10)
# Out:
# [(',', 65),
#  ('.', 50),
#  ('the', 49),
#  ('and', 45),
#  ('to', 43),
#  ('of', 33),
#  ('our', 31),
#  ('a', 28),
#  ('we', 27),
#  ('for', 23)]

# %%
# Find the first 20 most common words in Carter's speech
f.most_common(20)
# Out:
# [(',', 65),
#  ('.', 50),
#  ('the', 49),
#  ('and', 45),
#  ('to', 43),
#  ('of', 33),
#  ('our', 31),
#  ('a', 28),
#  ('we', 27),
#  ('for', 23),
#  ('that', 22),
#  ('in', 20),
#  ('be', 18),
#  ('We', 16),
#  ('is', 15),
#  ('can', 13),
#  ('but', 12),
#  ('Nation', 11),
#  ('not', 10),
#  ('on', 9)]

# %%
# n-gram generation

from nltk.util import ngrams
# function to get n-grams from sentences.
def extract_ngrams(data, num):
    nGrams = ngrams(data, num)
    return [ ' '.join(grams) for grams in nGrams]

# %%
x = brown.words(categories = ['adventure'])
extract_ngrams(x, 2)
# Out:
# ['Dan Morgan',
#  'Morgan told',
#  'told himself',
#  'himself he',
#  'he would',
#  'would forget',
#  'forget Ann',
#  'Ann Turner',
#  'Turner .',
#  '. He',
#  'He was',
#  'was well',
#  'well rid',
#  'rid of',
#  'of her',
#  'her .',
#  '. He',
#  'He certainly',
#  "certainly didn't",
#  "didn't want",
#  'want a',
#  'a wife',
#  'wife who',
#  'who was',
#  'was fickle',
#  'fickle as',
#  'as Ann',
#  'Ann .',
#  '. If',
#  'If he',
#  'he had',
#  'had married',
#  'married her',
#  'her ,',
#  ", he'd",
#  "he'd have",
#  'have been',
#  'been asking',
#  'asking for',
#  'for trouble',
#  'trouble .',
#  '. But',
#  'But all',
#  'all of',
#  'of this',
#  'this was',
#  'was rationalization',
#  'rationalization .',
#  '. Sometimes',
#  'Sometimes he',
#  'he woke',
#  'woke up',
#  'up in',
#  'in the',
#  'the middle',
#  'middle of',
#  'of the',
#  'the night',
#  'night thinking',
#  'thinking of',
#  'of Ann',
#  'Ann ,',
#  ', and',
#  'and then',
#  'then could',
#  'could not',
#  'not get',
#  'get back',
#  'back to',
#  'to sleep',
#  'sleep .',
#  '. His',
#  'His plans',
#  'plans and',
#  'and dreams',
#  'dreams had',
#  'had revolved',
#  'revolved around',
#  'around her',
#  'her so',
#  'so much',
#  'much and',
#  'and for',
#  'for so',
#  'so long',
#  'long that',
#  'that now',
#  'now he',
#  'he felt',
#  'felt as',
#  'as if',
#  'if he',
#  'he had',
#  'had nothing',
#  'nothing .',
#  '. The',
#  'The easiest',
#  'easiest thing',
#  'thing would',
#  'would be',
#  'be to',
#  'to sell',
#  'sell out',
#  'out to',
#  'to Al',
#  'Al Budd',
#  'Budd and',
#  'and leave',
#  'leave the',
#  'the country',
#  'country ,',
#  ', but',
#  'but there',
#  'there was',
#  'was a',
#  'a stubborn',
#  'stubborn streak',
#  'streak in',
#  'in him',
#  'him that',
#  "that wouldn't",
#  "wouldn't allow",
#  'allow it',
#  'it .',
#  '. The',
#  'The best',
#  'best antidote',
#  'antidote for',
#  'for the',
#  'the bitterness',
#  'bitterness and',
#  'and disappointment',
#  'disappointment that',
#  'that poisoned',
#  'poisoned him',
#  'him was',
#  'was hard',
#  'hard work',
#  'work .',
#  '. He',
#  'He found',
#  'found that',
#  'that if',
#  'if he',
#  'he was',
#  'was tired',
#  'tired enough',
#  'enough at',
#  'at night',
#  'night ,',
#  ', he',
#  'he went',
#  'went to',
#  'to sleep',
#  'sleep simply',
#  'simply because',
#  'because he',
#  'he was',
#  'was too',
#  'too exhausted',
#  'exhausted to',
#  'to stay',
#  'stay awake',
#  'awake .',
#  '. Each',
#  'Each day',
#  'day he',
#  'he found',
#  'found himself',
#  'himself thinking',
#  'thinking less',
#  'less often',
#  'often of',
#  'of Ann',
#  'Ann ;',
#  '; ;',
#  '; each',
#  'each day',
#  'day the',
#  'the hurt',
#  'hurt was',
#  'was a',
#  'a little',
#  'little duller',
#  'duller ,',
#  ', a',
#  'a little',
#  'little less',
#  'less poignant',
#  'poignant .',
#  '. He',
#  'He had',
#  'had plenty',
#  'plenty of',
#  'of work',
#  'work to',
#  'to do',
#  'do .',
#  '. Because',
#  'Because the',
#  'the summer',
#  'summer was',
#  'was unusually',
#  'unusually dry',
#  'dry and',
#  'and hot',
#  'hot ,',
#  ', the',
#  'the spring',
#  'spring produced',
#  'produced a',
#  'a smaller',
#  'smaller stream',
#  'stream than',
#  'than in',
#  'in ordinary',
#  'ordinary years',
#  'years .',
#  '. The',
#  'The grass',
#  'grass in',
#  'in the',
#  'the meadows',
#  'meadows came',
#  'came fast',
#  'fast ,',
#  ', now',
#  'now that',
#  'that the',
#  'the warm',
#  'warm weather',
#  'weather was',
#  'was here',
#  'here .',
#  '. He',
#  'He could',
#  'could not',
#  'not afford',
#  'afford to',
#  'to lose',
#  'lose a',
#  'a drop',
#  'drop of',
#  'of the',
#  'the precious',
#  'precious water',
#  'water ,',
#  ', so',
#  'so he',
#  'he spent',
#  'spent most',
#  'most of',
#  'of his',
#  'his waking',
#  'waking hours',
#  'hours along',
#  'along the',
#  'the ditches',
#  'ditches in',
#  'in his',
#  'his meadows',
#  'meadows .',
#  '. He',
#  'He had',
#  'had no',
#  'no idea',
#  'idea how',
#  'how much',
#  'much time',
#  'time Budd',
#  'Budd would',
#  'would give',
#  'give him',
#  'him .',
#  '. In',
#  'In any',
#  'any case',
#  'case ,',
#  ', he',
#  'he had',
#  'had no',
#  'no intention',
#  'intention of',
#  'of being',
#  'being caught',
#  'caught asleep',
#  'asleep ,',
#  ', so',
#  'so he',
#  'he carried',
#  'carried his',
#  'his revolver',
#  'revolver in',
#  'in its',
#  'its holster',
#  'holster on',
#  'on his',
#  'his hip',
#  'hip and',
#  'and he',
#  'he took',
#  'took his',
#  'his Winchester',
#  'Winchester with',
#  'with him',
#  'him and',
#  'and leaned',
#  'leaned it',
#  'it against',
#  'against the',
#  'the fence',
#  'fence .',
#  '. He',
#  'He stopped',
#  'stopped every',
#  'every few',
#  'few minutes',
#  'minutes and',
#  'and leaned',
#  'leaned on',
#  'on his',
#  'his shovel',
#  'shovel as',
#  'as he',
#  'he studied',
#  'studied the',
#  'the horizon',
#  'horizon ,',
#  ', but',
#  'but nothing',
#  'nothing happened',
#  'happened ,',
#  ', each',
#  'each day',
#  'day dragging',
#  'dragging out',
#  'out with',
#  'with monotonous',
#  'monotonous calm',
#  'calm .',
#  '. When',
#  'When ,',
#  ', in',
#  'in late',
#  'late afternoon',
#  'afternoon on',
#  'on the',
#  'the last',
#  'last day',
#  'day in',
#  'in June',
#  'June ,',
#  ', he',
#  'he saw',
#  'saw two',
#  'two people',
#  'people top',
#  'top the',
#  'the ridge',
#  'ridge to',
#  'to the',
#  'the south',
#  'south and',
#  'and walk',
#  'walk toward',
#  'toward the',
#  'the house',
#  'house ,',
#  ', he',
#  'he quit',
#  'quit work',
#  'work immediately',
#  'immediately and',
#  'and strode',
#  'strode to',
#  'to his',
#  'his rifle',
#  'rifle .',
#  '. It',
#  'It could',
#  'could be',
#  'be some',
#  'some kind',
#  'kind of',
#  'of trick',
#  'trick Budd',
#  'Budd had',
#  'had thought',
#  'thought up',
#  'up .',
#  '. No',
#  'No one',
#  'one walked',
#  'walked in',
#  'in this',
#  'this country',
#  'country ,',
#  ', least',
#  'least of',
#  'of all',
#  'all Ed',
#  'Ed Dow',
#  'Dow or',
#  'or Dutch',
#  'Dutch Renfro',
#  'Renfro or',
#  'or any',
#  'any of',
#  'of the',
#  'the rest',
#  'rest of',
#  'of the',
#  'the Bar',
#  'Bar B',
#  'B crew',
#  'crew .',
#  '. Morgan',
#  'Morgan watched',
#  'watched the',
#  'the two',
#  'two figures',
#  'figures for',
#  'for a',
#  'a time',
#  'time ,',
#  ', puzzled',
#  'puzzled .',
#  '. When',
#  'When they',
#  'they were',
#  'were closer',
#  'closer and',
#  'and he',
#  'he saw',
#  'saw that',
#  'that one',
#  'one was',
#  'was a',
#  'a woman',
#  'woman ,',
#  ', he',
#  'he was',
#  'was more',
#  'more puzzled',
#  'puzzled than',
#  'than ever',
#  'ever .',
#  '. He',
#  'He cleaned',
#  'cleaned his',
#  'his shovel',
#  'shovel ,',
#  ', left',
#  'left it',
#  'it against',
#  'against the',
#  'the fence',
#  'fence ,',
#  ', picked',
#  'picked up',
#  'up his',
#  'his Winchester',
#  'Winchester ,',
#  ', and',
#  'and started',
#  'started downstream',
#  'downstream .',
#  '. His',
#  'His visitors',
#  'visitors had',
#  'had crawled',
#  'crawled through',
#  'through the',
#  'the south',
#  'south fence',
#  'fence and',
#  'and were',
#  'were crossing',
#  'crossing the',
#  'the meadow',
#  'meadow ,',
#  ', angling',
#  'angling toward',
#  'toward the',
#  'the house',
#  'house .',
#  '. Now',
#  'Now he',
#  'he saw',
#  'saw that',
#  'that both',
#  'both the',
#  'the man',
#  'man and',
#  'and woman',
#  'woman were',
#  'were moving',
#  'moving slowly',
#  'slowly and',
#  'and irregularly',
#  'irregularly ,',
#  ', staggering',
#  'staggering ,',
#  ', as',
#  'as if',
#  'if they',
#  'they found',
#  'found it',
#  'it a',
#  'a struggle',
#  'struggle to',
#  'to remain',
#  'remain on',
#  'on their',
#  'their feet',
#  'feet .',
#  '. Reaching',
#  'Reaching the',
#  'the house',
#  'house ahead',
#  'ahead of',
#  'of them',
#  'them ,',
#  ', he',
#  'he waited',
#  'waited with',
#  'with his',
#  'his Winchester',
#  'Winchester in',
#  'in his',
#  'his hands',
#  'hands .',
#  '. They',
#  'They crawled',
#  'crawled through',
#  'through the',
#  'the north',
#  'north fence',
#  'fence and',
#  'and came',
#  'came on',
#  'on toward',
#  'toward him',
#  'him ,',
#  ', and',
#  'and now',
#  'now he',
#  'he saw',
#  'saw that',
#  'that both',
#  'both were',
#  'were young',
#  'young ,',
#  ', not',
#  'not more',
#  'more than',
#  'than nineteen',
#  'nineteen or',
#  'or twenty',
#  'twenty .',
#  '. They',
#  'They were',
#  'were dirty',
#  'dirty ,',
#  ', their',
#  'their clothes',
#  'clothes were',
#  'were torn',
#  'torn ,',
#  ', and',
#  'and the',
#  'the girl',
#  'girl was',
#  'was so',
#  'so exhausted',
#  'exhausted that',
#  'that she',
#  'she fell',
#  'fell when',
#  'when she',
#  'she was',
#  'was still',
#  'still twenty',
#  'twenty feet',
#  'feet from',
#  'from the',
#  'the front',
#  'front door',
#  'door .',
#  '. She',
#  'She lay',
#  'lay there',
#  'there ,',
#  ', making',
#  'making no',
#  'no effort',
#  'effort to',
#  'to get',
#  'get back',
#  'back on',
#  'on her',
#  'her feet',
#  'feet .',
#  '. The',
#  'The boy',
#  'boy came',
#  'came on',
#  'on to',
#  'to the',
#  'the porch',
#  'porch and',
#  'and sat',
#  'sat down',
#  'down ,',
#  ', his',
#  'his gaze',
#  'gaze on',
#  'on Morgan',
#  'Morgan as',
#  'as if',
#  'if half',
#  'half expecting',
#  'expecting him',
#  'him to',
#  'to shoot',
#  'shoot and',
#  'and not',
#  'not really',
#  'really caring',
#  'caring .',
#  '. Morgan',
#  'Morgan hesitated',
#  'hesitated ,',
#  ', thinking',
#  'thinking that',
#  'that if',
#  'if this',
#  'this was',
#  'was a',
#  'a trick',
#  'trick ,',
#  ', it',
#  'it was',
#  'was a',
#  'a good',
#  'good one',
#  'one .',
#  '. He',
#  "He didn't",
#  "didn't think",
#  'think it',
#  'it was',
#  'was possible',
#  'possible for',
#  'for this',
#  'this couple',
#  'couple to',
#  'to be',
#  'be pretending',
#  'pretending .',
#  '. The',
#  'The boy',
#  'boy licked',
#  'licked his',
#  'his dry',
#  'dry lips',
#  'lips .',
#  '. He',
#  'He asked',
#  'asked ,',
#  ', ``',
#  '`` Could',
#  'Could we',
#  'we have',
#  'have a',
#  'a drink',
#  "drink ''",
#  "'' ?",
#  '? ?',
#  '? Morgan',
#  'Morgan jerked',
#  'jerked his',
#  'his head',
#  'head toward',
#  'toward the',
#  'the front',
#  'front door',
#  'door .',
#  '. ``',
#  '`` In',
#  'In the',
#  'the kitchen',
#  "kitchen ''",
#  "'' ,",
#  ', he',
#  'he said',
#  'said .',
#  '. Leaning',
#  'Leaning his',
#  'his Winchester',
#  'Winchester against',
#  'against the',
#  'the front',
#  'front of',
#  'of the',
#  'the house',
#  'house ,',
#  ', he',
#  'he walked',
#  'walked to',
#  'to the',
#  'the girl',
#  'girl .',
#  '. ``',
#  '`` Get',
#  'Get up',
#  'up .',
#  ". There's",
#  "There's water",
#  'water in',
#  'in the',
#  'the house',
#  "house ''",
#  "'' .",
#  '. She',
#  "She didn't",
#  "didn't move",
#  'move or',
#  'or say',
#  'say anything',
#  'anything .',
#  '. Her',
#  'Her eyes',
#  'eyes were',
#  'were glazed',
#  'glazed as',
#  'as if',
#  'if she',
#  "she didn't",
#  "didn't hear",
#  'hear or',
#  'or even',
#  'even see',
#  'see him',
#  'him .',
#  '. She',
#  'She had',
#  'had reached',
#  'reached a',
#  'a point',
#  'point at',
#  'at which',
#  'which she',
#  "she didn't",
#  "didn't even",
#  'even care',
#  'care how',
#  'how she',
#  'she looked',
#  'looked .',
#  '. Her',
#  'Her face',
#  'face was',
#  'was very',
#  'very thin',
#  'thin ,',
#  ', and',
#  'and burned',
#  'burned by',
#  'by the',
#  'the sun',
#  'sun until',
#  'until much',
#  'much of',
#  'of the',
#  'the skin',
#  'skin was',
#  'was dead',
#  'dead and',
#  'and peeling',
#  'peeling ,',
#  ', the',
#  'the new',
#  'new skin',
#  'skin under',
#  'under it',
#  'it red',
#  'red and',
#  'and angry',
#  'angry .',
#  '. Her',
#  'Her blond',
#  'blond hair',
#  'hair was',
#  'was frowzy',
#  'frowzy ,',
#  ', her',
#  'her dress',
#  'dress torn',
#  'torn in',
#  'in several',
#  'several places',
#  'places ,',
#  ', and',
#  'and her',
#  'her shoes',
#  'shoes were',
#  'were so',
#  'so completely',
#  'completely worn',
#  'worn out',
#  'out that',
#  'that they',
#  'they were',
#  'were practically',
#  'practically no',
#  'no protection',
#  'protection .',
#  '. It',
#  'It must',
#  'must have',
#  'have hurt',
#  'hurt her',
#  'her even',
#  'even to',
#  'to walk',
#  'walk ,',
#  ', for',
#  'for the',
#  'the sole',
#  'sole was',
#  'was completely',
#  'completely off',
#  'off her',
#  'her left',
#  'left foot',
#  'foot and',
#  'and Morgan',
#  'Morgan saw',
#  'saw that',
#  'that it',
#  'it was',
#  'was bruised',
#  'bruised and',
#  'and bleeding',
#  'bleeding .',
#  '. He',
#  'He picked',
#  'picked her',
#  'her up',
#  'up ,',
#  ', sliding',
#  'sliding one',
#  'one hand',
#  'hand under',
#  'under her',
#  'her shoulders',
#  'shoulders ,',
#  ', the',
#  'the other',
#  'other under',
#  'under her',
#  'her knees',
#  'knees ,',
#  ', and',
#  'and carried',
#  'carried her',
#  'her into',
#  'into the',
#  'the house',
#  'house .',
#  '. She',
#  'She was',
#  'was amazingly',
#  'amazingly light',
#  'light ,',
#  ', and',
#  'and so',
#  'so relaxed',
#  'relaxed in',
#  'in his',
#  'his arms',
#  'arms that',
#  'that he',
#  "he wasn't",
#  "wasn't even",
#  'even sure',
#  'sure she',
#  'she was',
#  'was conscious',
#  'conscious .',
#  '. Any',
#  'Any lingering',
#  'lingering suspicion',
#  'suspicion that',
#  'that this',
#  'this was',
#  'was a',
#  'a trick',
#  'trick Al',
#  'Al Budd',
#  'Budd had',
#  'had thought',
#  'thought up',
#  'up was',
#  'was dispelled',
#  'dispelled .',
#  '. No',
#  'No girl',
#  'girl would',
#  'would go',
#  'go this',
#  'this far',
#  'far to',
#  'to fool',
#  'fool a',
#  'a man',
#  'man so',
#  'so she',
#  'she could',
#  'could kill',
#  'kill him',
#  'him .',
#  '. Besides',
#  'Besides ,',
#  ', she',
#  'she had',
#  'had a',
#  'a sweet',
#  'sweet face',
#  'face that',
#  'that attracted',
#  'attracted him',
#  'him .',
#  '. He',
#  'He put',
#  'put her',
#  'her down',
#  'down on',
#  'on the',
#  'the couch',
#  'couch ,',
#  ', and',
#  'and going',
#  'going into',
#  'into the',
#  'the kitchen',
#  'kitchen ,',
#  ', saw',
#  'saw that',
#  'that the',
#  'the boy',
#  'boy had',
#  'had dropped',
#  'dropped into',
#  'into a',
#  'a chair',
#  'chair beside',
#  'beside the',
#  'the table',
#  'table .',
#  '. They',
#  'They looked',
#  'looked a',
#  'a good',
#  'good deal',
#  'deal alike',
#  'alike ,',
#  ', Morgan',
#  'Morgan thought',
#  'thought .',
#  '. Both',
#  'Both had',
#  'had blonde',
#  'blonde hair',
#  'hair and',
#  'and blue',
#  'blue eyes',
#  'eyes ,',
#  ', and',
#  'and there',
#  'there was',
#  'was even',
#  'even a',
#  'a faint',
#  'faint similarity',
#  'similarity of',
#  'of features',
#  'features .',
#  '. Morgan',
#  'Morgan filled',
#  'filled the',
#  'the dipper',
#  'dipper from',
#  'from the',
#  'the water',
#  'water bucket',
#  'bucket on',
#  'on the',
#  'the shelf',
#  ...]

# %%
extract_ngrams(x, 3)
# Out:
# ['Dan Morgan told',
#  'Morgan told himself',
#  'told himself he',
#  'himself he would',
#  'he would forget',
#  'would forget Ann',
#  'forget Ann Turner',
#  'Ann Turner .',
#  'Turner . He',
#  '. He was',
#  'He was well',
#  'was well rid',
#  'well rid of',
#  'rid of her',
#  'of her .',
#  'her . He',
#  '. He certainly',
#  "He certainly didn't",
#  "certainly didn't want",
#  "didn't want a",
#  'want a wife',
#  'a wife who',
#  'wife who was',
#  'who was fickle',
#  'was fickle as',
#  'fickle as Ann',
#  'as Ann .',
#  'Ann . If',
#  '. If he',
#  'If he had',
#  'he had married',
#  'had married her',
#  'married her ,',
#  "her , he'd",
#  ", he'd have",
#  "he'd have been",
#  'have been asking',
#  'been asking for',
#  'asking for trouble',
#  'for trouble .',
#  'trouble . But',
#  '. But all',
#  'But all of',
#  'all of this',
#  'of this was',
#  'this was rationalization',
#  'was rationalization .',
#  'rationalization . Sometimes',
#  '. Sometimes he',
#  'Sometimes he woke',
#  'he woke up',
#  'woke up in',
#  'up in the',
#  'in the middle',
#  'the middle of',
#  'middle of the',
#  'of the night',
#  'the night thinking',
#  'night thinking of',
#  'thinking of Ann',
#  'of Ann ,',
#  'Ann , and',
#  ', and then',
#  'and then could',
#  'then could not',
#  'could not get',
#  'not get back',
#  'get back to',
#  'back to sleep',
#  'to sleep .',
#  'sleep . His',
#  '. His plans',
#  'His plans and',
#  'plans and dreams',
#  'and dreams had',
#  'dreams had revolved',
#  'had revolved around',
#  'revolved around her',
#  'around her so',
#  'her so much',
#  'so much and',
#  'much and for',
#  'and for so',
#  'for so long',
#  'so long that',
#  'long that now',
#  'that now he',
#  'now he felt',
#  'he felt as',
#  'felt as if',
#  'as if he',
#  'if he had',
#  'he had nothing',
#  'had nothing .',
#  'nothing . The',
#  '. The easiest',
#  'The easiest thing',
#  'easiest thing would',
#  'thing would be',
#  'would be to',
#  'be to sell',
#  'to sell out',
#  'sell out to',
#  'out to Al',
#  'to Al Budd',
#  'Al Budd and',
#  'Budd and leave',
#  'and leave the',
#  'leave the country',
#  'the country ,',
#  'country , but',
#  ', but there',
#  'but there was',
#  'there was a',
#  'was a stubborn',
#  'a stubborn streak',
#  'stubborn streak in',
#  'streak in him',
#  'in him that',
#  "him that wouldn't",
#  "that wouldn't allow",
#  "wouldn't allow it",
#  'allow it .',
#  'it . The',
#  '. The best',
#  'The best antidote',
#  'best antidote for',
#  'antidote for the',
#  'for the bitterness',
#  'the bitterness and',
#  'bitterness and disappointment',
#  'and disappointment that',
#  'disappointment that poisoned',
#  'that poisoned him',
#  'poisoned him was',
#  'him was hard',
#  'was hard work',
#  'hard work .',
#  'work . He',
#  '. He found',
#  'He found that',
#  'found that if',
#  'that if he',
#  'if he was',
#  'he was tired',
#  'was tired enough',
#  'tired enough at',
#  'enough at night',
#  'at night ,',
#  'night , he',
#  ', he went',
#  'he went to',
#  'went to sleep',
#  'to sleep simply',
#  'sleep simply because',
#  'simply because he',
#  'because he was',
#  'he was too',
#  'was too exhausted',
#  'too exhausted to',
#  'exhausted to stay',
#  'to stay awake',
#  'stay awake .',
#  'awake . Each',
#  '. Each day',
#  'Each day he',
#  'day he found',
#  'he found himself',
#  'found himself thinking',
#  'himself thinking less',
#  'thinking less often',
#  'less often of',
#  'often of Ann',
#  'of Ann ;',
#  'Ann ; ;',
#  '; ; each',
#  '; each day',
#  'each day the',
#  'day the hurt',
#  'the hurt was',
#  'hurt was a',
#  'was a little',
#  'a little duller',
#  'little duller ,',
#  'duller , a',
#  ', a little',
#  'a little less',
#  'little less poignant',
#  'less poignant .',
#  'poignant . He',
#  '. He had',
#  'He had plenty',
#  'had plenty of',
#  'plenty of work',
#  'of work to',
#  'work to do',
#  'to do .',
#  'do . Because',
#  '. Because the',
#  'Because the summer',
#  'the summer was',
#  'summer was unusually',
#  'was unusually dry',
#  'unusually dry and',
#  'dry and hot',
#  'and hot ,',
#  'hot , the',
#  ', the spring',
#  'the spring produced',
#  'spring produced a',
#  'produced a smaller',
#  'a smaller stream',
#  'smaller stream than',
#  'stream than in',
#  'than in ordinary',
#  'in ordinary years',
#  'ordinary years .',
#  'years . The',
#  '. The grass',
#  'The grass in',
#  'grass in the',
#  'in the meadows',
#  'the meadows came',
#  'meadows came fast',
#  'came fast ,',
#  'fast , now',
#  ', now that',
#  'now that the',
#  'that the warm',
#  'the warm weather',
#  'warm weather was',
#  'weather was here',
#  'was here .',
#  'here . He',
#  '. He could',
#  'He could not',
#  'could not afford',
#  'not afford to',
#  'afford to lose',
#  'to lose a',
#  'lose a drop',
#  'a drop of',
#  'drop of the',
#  'of the precious',
#  'the precious water',
#  'precious water ,',
#  'water , so',
#  ', so he',
#  'so he spent',
#  'he spent most',
#  'spent most of',
#  'most of his',
#  'of his waking',
#  'his waking hours',
#  'waking hours along',
#  'hours along the',
#  'along the ditches',
#  'the ditches in',
#  'ditches in his',
#  'in his meadows',
#  'his meadows .',
#  'meadows . He',
#  '. He had',
#  'He had no',
#  'had no idea',
#  'no idea how',
#  'idea how much',
#  'how much time',
#  'much time Budd',
#  'time Budd would',
#  'Budd would give',
#  'would give him',
#  'give him .',
#  'him . In',
#  '. In any',
#  'In any case',
#  'any case ,',
#  'case , he',
#  ', he had',
#  'he had no',
#  'had no intention',
#  'no intention of',
#  'intention of being',
#  'of being caught',
#  'being caught asleep',
#  'caught asleep ,',
#  'asleep , so',
#  ', so he',
#  'so he carried',
#  'he carried his',
#  'carried his revolver',
#  'his revolver in',
#  'revolver in its',
#  'in its holster',
#  'its holster on',
#  'holster on his',
#  'on his hip',
#  'his hip and',
#  'hip and he',
#  'and he took',
#  'he took his',
#  'took his Winchester',
#  'his Winchester with',
#  'Winchester with him',
#  'with him and',
#  'him and leaned',
#  'and leaned it',
#  'leaned it against',
#  'it against the',
#  'against the fence',
#  'the fence .',
#  'fence . He',
#  '. He stopped',
#  'He stopped every',
#  'stopped every few',
#  'every few minutes',
#  'few minutes and',
#  'minutes and leaned',
#  'and leaned on',
#  'leaned on his',
#  'on his shovel',
#  'his shovel as',
#  'shovel as he',
#  'as he studied',
#  'he studied the',
#  'studied the horizon',
#  'the horizon ,',
#  'horizon , but',
#  ', but nothing',
#  'but nothing happened',
#  'nothing happened ,',
#  'happened , each',
#  ', each day',
#  'each day dragging',
#  'day dragging out',
#  'dragging out with',
#  'out with monotonous',
#  'with monotonous calm',
#  'monotonous calm .',
#  'calm . When',
#  '. When ,',
#  'When , in',
#  ', in late',
#  'in late afternoon',
#  'late afternoon on',
#  'afternoon on the',
#  'on the last',
#  'the last day',
#  'last day in',
#  'day in June',
#  'in June ,',
#  'June , he',
#  ', he saw',
#  'he saw two',
#  'saw two people',
#  'two people top',
#  'people top the',
#  'top the ridge',
#  'the ridge to',
#  'ridge to the',
#  'to the south',
#  'the south and',
#  'south and walk',
#  'and walk toward',
#  'walk toward the',
#  'toward the house',
#  'the house ,',
#  'house , he',
#  ', he quit',
#  'he quit work',
#  'quit work immediately',
#  'work immediately and',
#  'immediately and strode',
#  'and strode to',
#  'strode to his',
#  'to his rifle',
#  'his rifle .',
#  'rifle . It',
#  '. It could',
#  'It could be',
#  'could be some',
#  'be some kind',
#  'some kind of',
#  'kind of trick',
#  'of trick Budd',
#  'trick Budd had',
#  'Budd had thought',
#  'had thought up',
#  'thought up .',
#  'up . No',
#  '. No one',
#  'No one walked',
#  'one walked in',
#  'walked in this',
#  'in this country',
#  'this country ,',
#  'country , least',
#  ', least of',
#  'least of all',
#  'of all Ed',
#  'all Ed Dow',
#  'Ed Dow or',
#  'Dow or Dutch',
#  'or Dutch Renfro',
#  'Dutch Renfro or',
#  'Renfro or any',
#  'or any of',
#  'any of the',
#  'of the rest',
#  'the rest of',
#  'rest of the',
#  'of the Bar',
#  'the Bar B',
#  'Bar B crew',
#  'B crew .',
#  'crew . Morgan',
#  '. Morgan watched',
#  'Morgan watched the',
#  'watched the two',
#  'the two figures',
#  'two figures for',
#  'figures for a',
#  'for a time',
#  'a time ,',
#  'time , puzzled',
#  ', puzzled .',
#  'puzzled . When',
#  '. When they',
#  'When they were',
#  'they were closer',
#  'were closer and',
#  'closer and he',
#  'and he saw',
#  'he saw that',
#  'saw that one',
#  'that one was',
#  'one was a',
#  'was a woman',
#  'a woman ,',
#  'woman , he',
#  ', he was',
#  'he was more',
#  'was more puzzled',
#  'more puzzled than',
#  'puzzled than ever',
#  'than ever .',
#  'ever . He',
#  '. He cleaned',
#  'He cleaned his',
#  'cleaned his shovel',
#  'his shovel ,',
#  'shovel , left',
#  ', left it',
#  'left it against',
#  'it against the',
#  'against the fence',
#  'the fence ,',
#  'fence , picked',
#  ', picked up',
#  'picked up his',
#  'up his Winchester',
#  'his Winchester ,',
#  'Winchester , and',
#  ', and started',
#  'and started downstream',
#  'started downstream .',
#  'downstream . His',
#  '. His visitors',
#  'His visitors had',
#  'visitors had crawled',
#  'had crawled through',
#  'crawled through the',
#  'through the south',
#  'the south fence',
#  'south fence and',
#  'fence and were',
#  'and were crossing',
#  'were crossing the',
#  'crossing the meadow',
#  'the meadow ,',
#  'meadow , angling',
#  ', angling toward',
#  'angling toward the',
#  'toward the house',
#  'the house .',
#  'house . Now',
#  '. Now he',
#  'Now he saw',
#  'he saw that',
#  'saw that both',
#  'that both the',
#  'both the man',
#  'the man and',
#  'man and woman',
#  'and woman were',
#  'woman were moving',
#  'were moving slowly',
#  'moving slowly and',
#  'slowly and irregularly',
#  'and irregularly ,',
#  'irregularly , staggering',
#  ', staggering ,',
#  'staggering , as',
#  ', as if',
#  'as if they',
#  'if they found',
#  'they found it',
#  'found it a',
#  'it a struggle',
#  'a struggle to',
#  'struggle to remain',
#  'to remain on',
#  'remain on their',
#  'on their feet',
#  'their feet .',
#  'feet . Reaching',
#  '. Reaching the',
#  'Reaching the house',
#  'the house ahead',
#  'house ahead of',
#  'ahead of them',
#  'of them ,',
#  'them , he',
#  ', he waited',
#  'he waited with',
#  'waited with his',
#  'with his Winchester',
#  'his Winchester in',
#  'Winchester in his',
#  'in his hands',
#  'his hands .',
#  'hands . They',
#  '. They crawled',
#  'They crawled through',
#  'crawled through the',
#  'through the north',
#  'the north fence',
#  'north fence and',
#  'fence and came',
#  'and came on',
#  'came on toward',
#  'on toward him',
#  'toward him ,',
#  'him , and',
#  ', and now',
#  'and now he',
#  'now he saw',
#  'he saw that',
#  'saw that both',
#  'that both were',
#  'both were young',
#  'were young ,',
#  'young , not',
#  ', not more',
#  'not more than',
#  'more than nineteen',
#  'than nineteen or',
#  'nineteen or twenty',
#  'or twenty .',
#  'twenty . They',
#  '. They were',
#  'They were dirty',
#  'were dirty ,',
#  'dirty , their',
#  ', their clothes',
#  'their clothes were',
#  'clothes were torn',
#  'were torn ,',
#  'torn , and',
#  ', and the',
#  'and the girl',
#  'the girl was',
#  'girl was so',
#  'was so exhausted',
#  'so exhausted that',
#  'exhausted that she',
#  'that she fell',
#  'she fell when',
#  'fell when she',
#  'when she was',
#  'she was still',
#  'was still twenty',
#  'still twenty feet',
#  'twenty feet from',
#  'feet from the',
#  'from the front',
#  'the front door',
#  'front door .',
#  'door . She',
#  '. She lay',
#  'She lay there',
#  'lay there ,',
#  'there , making',
#  ', making no',
#  'making no effort',
#  'no effort to',
#  'effort to get',
#  'to get back',
#  'get back on',
#  'back on her',
#  'on her feet',
#  'her feet .',
#  'feet . The',
#  '. The boy',
#  'The boy came',
#  'boy came on',
#  'came on to',
#  'on to the',
#  'to the porch',
#  'the porch and',
#  'porch and sat',
#  'and sat down',
#  'sat down ,',
#  'down , his',
#  ', his gaze',
#  'his gaze on',
#  'gaze on Morgan',
#  'on Morgan as',
#  'Morgan as if',
#  'as if half',
#  'if half expecting',
#  'half expecting him',
#  'expecting him to',
#  'him to shoot',
#  'to shoot and',
#  'shoot and not',
#  'and not really',
#  'not really caring',
#  'really caring .',
#  'caring . Morgan',
#  '. Morgan hesitated',
#  'Morgan hesitated ,',
#  'hesitated , thinking',
#  ', thinking that',
#  'thinking that if',
#  'that if this',
#  'if this was',
#  'this was a',
#  'was a trick',
#  'a trick ,',
#  'trick , it',
#  ', it was',
#  'it was a',
#  'was a good',
#  'a good one',
#  'good one .',
#  'one . He',
#  ". He didn't",
#  "He didn't think",
#  "didn't think it",
#  'think it was',
#  'it was possible',
#  'was possible for',
#  'possible for this',
#  'for this couple',
#  'this couple to',
#  'couple to be',
#  'to be pretending',
#  'be pretending .',
#  'pretending . The',
#  '. The boy',
#  'The boy licked',
#  'boy licked his',
#  'licked his dry',
#  'his dry lips',
#  'dry lips .',
#  'lips . He',
#  '. He asked',
#  'He asked ,',
#  'asked , ``',
#  ', `` Could',
#  '`` Could we',
#  'Could we have',
#  'we have a',
#  'have a drink',
#  "a drink ''",
#  "drink '' ?",
#  "'' ? ?",
#  '? ? Morgan',
#  '? Morgan jerked',
#  'Morgan jerked his',
#  'jerked his head',
#  'his head toward',
#  'head toward the',
#  'toward the front',
#  'the front door',
#  'front door .',
#  'door . ``',
#  '. `` In',
#  '`` In the',
#  'In the kitchen',
#  "the kitchen ''",
#  "kitchen '' ,",
#  "'' , he",
#  ', he said',
#  'he said .',
#  'said . Leaning',
#  '. Leaning his',
#  'Leaning his Winchester',
#  'his Winchester against',
#  'Winchester against the',
#  'against the front',
#  'the front of',
#  'front of the',
#  'of the house',
#  'the house ,',
#  'house , he',
#  ', he walked',
#  'he walked to',
#  'walked to the',
#  'to the girl',
#  'the girl .',
#  'girl . ``',
#  '. `` Get',
#  '`` Get up',
#  'Get up .',
#  "up . There's",
#  ". There's water",
#  "There's water in",
#  'water in the',
#  'in the house',
#  "the house ''",
#  "house '' .",
#  "'' . She",
#  ". She didn't",
#  "She didn't move",
#  "didn't move or",
#  'move or say',
#  'or say anything',
#  'say anything .',
#  'anything . Her',
#  '. Her eyes',
#  'Her eyes were',
#  'eyes were glazed',
#  'were glazed as',
#  'glazed as if',
#  'as if she',
#  "if she didn't",
#  "she didn't hear",
#  "didn't hear or",
#  'hear or even',
#  'or even see',
#  'even see him',
#  'see him .',
#  'him . She',
#  '. She had',
#  'She had reached',
#  'had reached a',
#  'reached a point',
#  'a point at',
#  'point at which',
#  'at which she',
#  "which she didn't",
#  "she didn't even",
#  "didn't even care",
#  'even care how',
#  'care how she',
#  'how she looked',
#  'she looked .',
#  'looked . Her',
#  '. Her face',
#  'Her face was',
#  'face was very',
#  'was very thin',
#  'very thin ,',
#  'thin , and',
#  ', and burned',
#  'and burned by',
#  'burned by the',
#  'by the sun',
#  'the sun until',
#  'sun until much',
#  'until much of',
#  'much of the',
#  'of the skin',
#  'the skin was',
#  'skin was dead',
#  'was dead and',
#  'dead and peeling',
#  'and peeling ,',
#  'peeling , the',
#  ', the new',
#  'the new skin',
#  'new skin under',
#  'skin under it',
#  'under it red',
#  'it red and',
#  'red and angry',
#  'and angry .',
#  'angry . Her',
#  '. Her blond',
#  'Her blond hair',
#  'blond hair was',
#  'hair was frowzy',
#  'was frowzy ,',
#  'frowzy , her',
#  ', her dress',
#  'her dress torn',
#  'dress torn in',
#  'torn in several',
#  'in several places',
#  'several places ,',
#  'places , and',
#  ', and her',
#  'and her shoes',
#  'her shoes were',
#  'shoes were so',
#  'were so completely',
#  'so completely worn',
#  'completely worn out',
#  'worn out that',
#  'out that they',
#  'that they were',
#  'they were practically',
#  'were practically no',
#  'practically no protection',
#  'no protection .',
#  'protection . It',
#  '. It must',
#  'It must have',
#  'must have hurt',
#  'have hurt her',
#  'hurt her even',
#  'her even to',
#  'even to walk',
#  'to walk ,',
#  'walk , for',
#  ', for the',
#  'for the sole',
#  'the sole was',
#  'sole was completely',
#  'was completely off',
#  'completely off her',
#  'off her left',
#  'her left foot',
#  'left foot and',
#  'foot and Morgan',
#  'and Morgan saw',
#  'Morgan saw that',
#  'saw that it',
#  'that it was',
#  'it was bruised',
#  'was bruised and',
#  'bruised and bleeding',
#  'and bleeding .',
#  'bleeding . He',
#  '. He picked',
#  'He picked her',
#  'picked her up',
#  'her up ,',
#  'up , sliding',
#  ', sliding one',
#  'sliding one hand',
#  'one hand under',
#  'hand under her',
#  'under her shoulders',
#  'her shoulders ,',
#  'shoulders , the',
#  ', the other',
#  'the other under',
#  'other under her',
#  'under her knees',
#  'her knees ,',
#  'knees , and',
#  ', and carried',
#  'and carried her',
#  'carried her into',
#  'her into the',
#  'into the house',
#  'the house .',
#  'house . She',
#  '. She was',
#  'She was amazingly',
#  'was amazingly light',
#  'amazingly light ,',
#  'light , and',
#  ', and so',
#  'and so relaxed',
#  'so relaxed in',
#  'relaxed in his',
#  'in his arms',
#  'his arms that',
#  'arms that he',
#  "that he wasn't",
#  "he wasn't even",
#  "wasn't even sure",
#  'even sure she',
#  'sure she was',
#  'she was conscious',
#  'was conscious .',
#  'conscious . Any',
#  '. Any lingering',
#  'Any lingering suspicion',
#  'lingering suspicion that',
#  'suspicion that this',
#  'that this was',
#  'this was a',
#  'was a trick',
#  'a trick Al',
#  'trick Al Budd',
#  'Al Budd had',
#  'Budd had thought',
#  'had thought up',
#  'thought up was',
#  'up was dispelled',
#  'was dispelled .',
#  'dispelled . No',
#  '. No girl',
#  'No girl would',
#  'girl would go',
#  'would go this',
#  'go this far',
#  'this far to',
#  'far to fool',
#  'to fool a',
#  'fool a man',
#  'a man so',
#  'man so she',
#  'so she could',
#  'she could kill',
#  'could kill him',
#  'kill him .',
#  'him . Besides',
#  '. Besides ,',
#  'Besides , she',
#  ', she had',
#  'she had a',
#  'had a sweet',
#  'a sweet face',
#  'sweet face that',
#  'face that attracted',
#  'that attracted him',
#  'attracted him .',
#  'him . He',
#  '. He put',
#  'He put her',
#  'put her down',
#  'her down on',
#  'down on the',
#  'on the couch',
#  'the couch ,',
#  'couch , and',
#  ', and going',
#  'and going into',
#  'going into the',
#  'into the kitchen',
#  'the kitchen ,',
#  'kitchen , saw',
#  ', saw that',
#  'saw that the',
#  'that the boy',
#  'the boy had',
#  'boy had dropped',
#  'had dropped into',
#  'dropped into a',
#  'into a chair',
#  'a chair beside',
#  'chair beside the',
#  'beside the table',
#  'the table .',
#  'table . They',
#  '. They looked',
#  'They looked a',
#  'looked a good',
#  'a good deal',
#  'good deal alike',
#  'deal alike ,',
#  'alike , Morgan',
#  ', Morgan thought',
#  'Morgan thought .',
#  'thought . Both',
#  '. Both had',
#  'Both had blonde',
#  'had blonde hair',
#  'blonde hair and',
#  'hair and blue',
#  'and blue eyes',
#  'blue eyes ,',
#  'eyes , and',
#  ', and there',
#  'and there was',
#  'there was even',
#  'was even a',
#  'even a faint',
#  'a faint similarity',
#  'faint similarity of',
#  'similarity of features',
#  'of features .',
#  'features . Morgan',
#  '. Morgan filled',
#  'Morgan filled the',
#  'filled the dipper',
#  'the dipper from',
#  'dipper from the',
#  'from the water',
#  'the water bucket',
#  'water bucket on',
#  'bucket on the',
#  'on the shelf',
#  'the shelf ,',
#  ...]

# %%
extract_ngrams(x, 4)
# Out:
# ['Dan Morgan told himself',
#  'Morgan told himself he',
#  'told himself he would',
#  'himself he would forget',
#  'he would forget Ann',
#  'would forget Ann Turner',
#  'forget Ann Turner .',
#  'Ann Turner . He',
#  'Turner . He was',
#  '. He was well',
#  'He was well rid',
#  'was well rid of',
#  'well rid of her',
#  'rid of her .',
#  'of her . He',
#  'her . He certainly',
#  ". He certainly didn't",
#  "He certainly didn't want",
#  "certainly didn't want a",
#  "didn't want a wife",
#  'want a wife who',
#  'a wife who was',
#  'wife who was fickle',
#  'who was fickle as',
#  'was fickle as Ann',
#  'fickle as Ann .',
#  'as Ann . If',
#  'Ann . If he',
#  '. If he had',
#  'If he had married',
#  'he had married her',
#  'had married her ,',
#  "married her , he'd",
#  "her , he'd have",
#  ", he'd have been",
#  "he'd have been asking",
#  'have been asking for',
#  'been asking for trouble',
#  'asking for trouble .',
#  'for trouble . But',
#  'trouble . But all',
#  '. But all of',
#  'But all of this',
#  'all of this was',
#  'of this was rationalization',
#  'this was rationalization .',
#  'was rationalization . Sometimes',
#  'rationalization . Sometimes he',
#  '. Sometimes he woke',
#  'Sometimes he woke up',
#  'he woke up in',
#  'woke up in the',
#  'up in the middle',
#  'in the middle of',
#  'the middle of the',
#  'middle of the night',
#  'of the night thinking',
#  'the night thinking of',
#  'night thinking of Ann',
#  'thinking of Ann ,',
#  'of Ann , and',
#  'Ann , and then',
#  ', and then could',
#  'and then could not',
#  'then could not get',
#  'could not get back',
#  'not get back to',
#  'get back to sleep',
#  'back to sleep .',
#  'to sleep . His',
#  'sleep . His plans',
#  '. His plans and',
#  'His plans and dreams',
#  'plans and dreams had',
#  'and dreams had revolved',
#  'dreams had revolved around',
#  'had revolved around her',
#  'revolved around her so',
#  'around her so much',
#  'her so much and',
#  'so much and for',
#  'much and for so',
#  'and for so long',
#  'for so long that',
#  'so long that now',
#  'long that now he',
#  'that now he felt',
#  'now he felt as',
#  'he felt as if',
#  'felt as if he',
#  'as if he had',
#  'if he had nothing',
#  'he had nothing .',
#  'had nothing . The',
#  'nothing . The easiest',
#  '. The easiest thing',
#  'The easiest thing would',
#  'easiest thing would be',
#  'thing would be to',
#  'would be to sell',
#  'be to sell out',
#  'to sell out to',
#  'sell out to Al',
#  'out to Al Budd',
#  'to Al Budd and',
#  'Al Budd and leave',
#  'Budd and leave the',
#  'and leave the country',
#  'leave the country ,',
#  'the country , but',
#  'country , but there',
#  ', but there was',
#  'but there was a',
#  'there was a stubborn',
#  'was a stubborn streak',
#  'a stubborn streak in',
#  'stubborn streak in him',
#  'streak in him that',
#  "in him that wouldn't",
#  "him that wouldn't allow",
#  "that wouldn't allow it",
#  "wouldn't allow it .",
#  'allow it . The',
#  'it . The best',
#  '. The best antidote',
#  'The best antidote for',
#  'best antidote for the',
#  'antidote for the bitterness',
#  'for the bitterness and',
#  'the bitterness and disappointment',
#  'bitterness and disappointment that',
#  'and disappointment that poisoned',
#  'disappointment that poisoned him',
#  'that poisoned him was',
#  'poisoned him was hard',
#  'him was hard work',
#  'was hard work .',
#  'hard work . He',
#  'work . He found',
#  '. He found that',
#  'He found that if',
#  'found that if he',
#  'that if he was',
#  'if he was tired',
#  'he was tired enough',
#  'was tired enough at',
#  'tired enough at night',
#  'enough at night ,',
#  'at night , he',
#  'night , he went',
#  ', he went to',
#  'he went to sleep',
#  'went to sleep simply',
#  'to sleep simply because',
#  'sleep simply because he',
#  'simply because he was',
#  'because he was too',
#  'he was too exhausted',
#  'was too exhausted to',
#  'too exhausted to stay',
#  'exhausted to stay awake',
#  'to stay awake .',
#  'stay awake . Each',
#  'awake . Each day',
#  '. Each day he',
#  'Each day he found',
#  'day he found himself',
#  'he found himself thinking',
#  'found himself thinking less',
#  'himself thinking less often',
#  'thinking less often of',
#  'less often of Ann',
#  'often of Ann ;',
#  'of Ann ; ;',
#  'Ann ; ; each',
#  '; ; each day',
#  '; each day the',
#  'each day the hurt',
#  'day the hurt was',
#  'the hurt was a',
#  'hurt was a little',
#  'was a little duller',
#  'a little duller ,',
#  'little duller , a',
#  'duller , a little',
#  ', a little less',
#  'a little less poignant',
#  'little less poignant .',
#  'less poignant . He',
#  'poignant . He had',
#  '. He had plenty',
#  'He had plenty of',
#  'had plenty of work',
#  'plenty of work to',
#  'of work to do',
#  'work to do .',
#  'to do . Because',
#  'do . Because the',
#  '. Because the summer',
#  'Because the summer was',
#  'the summer was unusually',
#  'summer was unusually dry',
#  'was unusually dry and',
#  'unusually dry and hot',
#  'dry and hot ,',
#  'and hot , the',
#  'hot , the spring',
#  ', the spring produced',
#  'the spring produced a',
#  'spring produced a smaller',
#  'produced a smaller stream',
#  'a smaller stream than',
#  'smaller stream than in',
#  'stream than in ordinary',
#  'than in ordinary years',
#  'in ordinary years .',
#  'ordinary years . The',
#  'years . The grass',
#  '. The grass in',
#  'The grass in the',
#  'grass in the meadows',
#  'in the meadows came',
#  'the meadows came fast',
#  'meadows came fast ,',
#  'came fast , now',
#  'fast , now that',
#  ', now that the',
#  'now that the warm',
#  'that the warm weather',
#  'the warm weather was',
#  'warm weather was here',
#  'weather was here .',
#  'was here . He',
#  'here . He could',
#  '. He could not',
#  'He could not afford',
#  'could not afford to',
#  'not afford to lose',
#  'afford to lose a',
#  'to lose a drop',
#  'lose a drop of',
#  'a drop of the',
#  'drop of the precious',
#  'of the precious water',
#  'the precious water ,',
#  'precious water , so',
#  'water , so he',
#  ', so he spent',
#  'so he spent most',
#  'he spent most of',
#  'spent most of his',
#  'most of his waking',
#  'of his waking hours',
#  'his waking hours along',
#  'waking hours along the',
#  'hours along the ditches',
#  'along the ditches in',
#  'the ditches in his',
#  'ditches in his meadows',
#  'in his meadows .',
#  'his meadows . He',
#  'meadows . He had',
#  '. He had no',
#  'He had no idea',
#  'had no idea how',
#  'no idea how much',
#  'idea how much time',
#  'how much time Budd',
#  'much time Budd would',
#  'time Budd would give',
#  'Budd would give him',
#  'would give him .',
#  'give him . In',
#  'him . In any',
#  '. In any case',
#  'In any case ,',
#  'any case , he',
#  'case , he had',
#  ', he had no',
#  'he had no intention',
#  'had no intention of',
#  'no intention of being',
#  'intention of being caught',
#  'of being caught asleep',
#  'being caught asleep ,',
#  'caught asleep , so',
#  'asleep , so he',
#  ', so he carried',
#  'so he carried his',
#  'he carried his revolver',
#  'carried his revolver in',
#  'his revolver in its',
#  'revolver in its holster',
#  'in its holster on',
#  'its holster on his',
#  'holster on his hip',
#  'on his hip and',
#  'his hip and he',
#  'hip and he took',
#  'and he took his',
#  'he took his Winchester',
#  'took his Winchester with',
#  'his Winchester with him',
#  'Winchester with him and',
#  'with him and leaned',
#  'him and leaned it',
#  'and leaned it against',
#  'leaned it against the',
#  'it against the fence',
#  'against the fence .',
#  'the fence . He',
#  'fence . He stopped',
#  '. He stopped every',
#  'He stopped every few',
#  'stopped every few minutes',
#  'every few minutes and',
#  'few minutes and leaned',
#  'minutes and leaned on',
#  'and leaned on his',
#  'leaned on his shovel',
#  'on his shovel as',
#  'his shovel as he',
#  'shovel as he studied',
#  'as he studied the',
#  'he studied the horizon',
#  'studied the horizon ,',
#  'the horizon , but',
#  'horizon , but nothing',
#  ', but nothing happened',
#  'but nothing happened ,',
#  'nothing happened , each',
#  'happened , each day',
#  ', each day dragging',
#  'each day dragging out',
#  'day dragging out with',
#  'dragging out with monotonous',
#  'out with monotonous calm',
#  'with monotonous calm .',
#  'monotonous calm . When',
#  'calm . When ,',
#  '. When , in',
#  'When , in late',
#  ', in late afternoon',
#  'in late afternoon on',
#  'late afternoon on the',
#  'afternoon on the last',
#  'on the last day',
#  'the last day in',
#  'last day in June',
#  'day in June ,',
#  'in June , he',
#  'June , he saw',
#  ', he saw two',
#  'he saw two people',
#  'saw two people top',
#  'two people top the',
#  'people top the ridge',
#  'top the ridge to',
#  'the ridge to the',
#  'ridge to the south',
#  'to the south and',
#  'the south and walk',
#  'south and walk toward',
#  'and walk toward the',
#  'walk toward the house',
#  'toward the house ,',
#  'the house , he',
#  'house , he quit',
#  ', he quit work',
#  'he quit work immediately',
#  'quit work immediately and',
#  'work immediately and strode',
#  'immediately and strode to',
#  'and strode to his',
#  'strode to his rifle',
#  'to his rifle .',
#  'his rifle . It',
#  'rifle . It could',
#  '. It could be',
#  'It could be some',
#  'could be some kind',
#  'be some kind of',
#  'some kind of trick',
#  'kind of trick Budd',
#  'of trick Budd had',
#  'trick Budd had thought',
#  'Budd had thought up',
#  'had thought up .',
#  'thought up . No',
#  'up . No one',
#  '. No one walked',
#  'No one walked in',
#  'one walked in this',
#  'walked in this country',
#  'in this country ,',
#  'this country , least',
#  'country , least of',
#  ', least of all',
#  'least of all Ed',
#  'of all Ed Dow',
#  'all Ed Dow or',
#  'Ed Dow or Dutch',
#  'Dow or Dutch Renfro',
#  'or Dutch Renfro or',
#  'Dutch Renfro or any',
#  'Renfro or any of',
#  'or any of the',
#  'any of the rest',
#  'of the rest of',
#  'the rest of the',
#  'rest of the Bar',
#  'of the Bar B',
#  'the Bar B crew',
#  'Bar B crew .',
#  'B crew . Morgan',
#  'crew . Morgan watched',
#  '. Morgan watched the',
#  'Morgan watched the two',
#  'watched the two figures',
#  'the two figures for',
#  'two figures for a',
#  'figures for a time',
#  'for a time ,',
#  'a time , puzzled',
#  'time , puzzled .',
#  ', puzzled . When',
#  'puzzled . When they',
#  '. When they were',
#  'When they were closer',
#  'they were closer and',
#  'were closer and he',
#  'closer and he saw',
#  'and he saw that',
#  'he saw that one',
#  'saw that one was',
#  'that one was a',
#  'one was a woman',
#  'was a woman ,',
#  'a woman , he',
#  'woman , he was',
#  ', he was more',
#  'he was more puzzled',
#  'was more puzzled than',
#  'more puzzled than ever',
#  'puzzled than ever .',
#  'than ever . He',
#  'ever . He cleaned',
#  '. He cleaned his',
#  'He cleaned his shovel',
#  'cleaned his shovel ,',
#  'his shovel , left',
#  'shovel , left it',
#  ', left it against',
#  'left it against the',
#  'it against the fence',
#  'against the fence ,',
#  'the fence , picked',
#  'fence , picked up',
#  ', picked up his',
#  'picked up his Winchester',
#  'up his Winchester ,',
#  'his Winchester , and',
#  'Winchester , and started',
#  ', and started downstream',
#  'and started downstream .',
#  'started downstream . His',
#  'downstream . His visitors',
#  '. His visitors had',
#  'His visitors had crawled',
#  'visitors had crawled through',
#  'had crawled through the',
#  'crawled through the south',
#  'through the south fence',
#  'the south fence and',
#  'south fence and were',
#  'fence and were crossing',
#  'and were crossing the',
#  'were crossing the meadow',
#  'crossing the meadow ,',
#  'the meadow , angling',
#  'meadow , angling toward',
#  ', angling toward the',
#  'angling toward the house',
#  'toward the house .',
#  'the house . Now',
#  'house . Now he',
#  '. Now he saw',
#  'Now he saw that',
#  'he saw that both',
#  'saw that both the',
#  'that both the man',
#  'both the man and',
#  'the man and woman',
#  'man and woman were',
#  'and woman were moving',
#  'woman were moving slowly',
#  'were moving slowly and',
#  'moving slowly and irregularly',
#  'slowly and irregularly ,',
#  'and irregularly , staggering',
#  'irregularly , staggering ,',
#  ', staggering , as',
#  'staggering , as if',
#  ', as if they',
#  'as if they found',
#  'if they found it',
#  'they found it a',
#  'found it a struggle',
#  'it a struggle to',
#  'a struggle to remain',
#  'struggle to remain on',
#  'to remain on their',
#  'remain on their feet',
#  'on their feet .',
#  'their feet . Reaching',
#  'feet . Reaching the',
#  '. Reaching the house',
#  'Reaching the house ahead',
#  'the house ahead of',
#  'house ahead of them',
#  'ahead of them ,',
#  'of them , he',
#  'them , he waited',
#  ', he waited with',
#  'he waited with his',
#  'waited with his Winchester',
#  'with his Winchester in',
#  'his Winchester in his',
#  'Winchester in his hands',
#  'in his hands .',
#  'his hands . They',
#  'hands . They crawled',
#  '. They crawled through',
#  'They crawled through the',
#  'crawled through the north',
#  'through the north fence',
#  'the north fence and',
#  'north fence and came',
#  'fence and came on',
#  'and came on toward',
#  'came on toward him',
#  'on toward him ,',
#  'toward him , and',
#  'him , and now',
#  ', and now he',
#  'and now he saw',
#  'now he saw that',
#  'he saw that both',
#  'saw that both were',
#  'that both were young',
#  'both were young ,',
#  'were young , not',
#  'young , not more',
#  ', not more than',
#  'not more than nineteen',
#  'more than nineteen or',
#  'than nineteen or twenty',
#  'nineteen or twenty .',
#  'or twenty . They',
#  'twenty . They were',
#  '. They were dirty',
#  'They were dirty ,',
#  'were dirty , their',
#  'dirty , their clothes',
#  ', their clothes were',
#  'their clothes were torn',
#  'clothes were torn ,',
#  'were torn , and',
#  'torn , and the',
#  ', and the girl',
#  'and the girl was',
#  'the girl was so',
#  'girl was so exhausted',
#  'was so exhausted that',
#  'so exhausted that she',
#  'exhausted that she fell',
#  'that she fell when',
#  'she fell when she',
#  'fell when she was',
#  'when she was still',
#  'she was still twenty',
#  'was still twenty feet',
#  'still twenty feet from',
#  'twenty feet from the',
#  'feet from the front',
#  'from the front door',
#  'the front door .',
#  'front door . She',
#  'door . She lay',
#  '. She lay there',
#  'She lay there ,',
#  'lay there , making',
#  'there , making no',
#  ', making no effort',
#  'making no effort to',
#  'no effort to get',
#  'effort to get back',
#  'to get back on',
#  'get back on her',
#  'back on her feet',
#  'on her feet .',
#  'her feet . The',
#  'feet . The boy',
#  '. The boy came',
#  'The boy came on',
#  'boy came on to',
#  'came on to the',
#  'on to the porch',
#  'to the porch and',
#  'the porch and sat',
#  'porch and sat down',
#  'and sat down ,',
#  'sat down , his',
#  'down , his gaze',
#  ', his gaze on',
#  'his gaze on Morgan',
#  'gaze on Morgan as',
#  'on Morgan as if',
#  'Morgan as if half',
#  'as if half expecting',
#  'if half expecting him',
#  'half expecting him to',
#  'expecting him to shoot',
#  'him to shoot and',
#  'to shoot and not',
#  'shoot and not really',
#  'and not really caring',
#  'not really caring .',
#  'really caring . Morgan',
#  'caring . Morgan hesitated',
#  '. Morgan hesitated ,',
#  'Morgan hesitated , thinking',
#  'hesitated , thinking that',
#  ', thinking that if',
#  'thinking that if this',
#  'that if this was',
#  'if this was a',
#  'this was a trick',
#  'was a trick ,',
#  'a trick , it',
#  'trick , it was',
#  ', it was a',
#  'it was a good',
#  'was a good one',
#  'a good one .',
#  'good one . He',
#  "one . He didn't",
#  ". He didn't think",
#  "He didn't think it",
#  "didn't think it was",
#  'think it was possible',
#  'it was possible for',
#  'was possible for this',
#  'possible for this couple',
#  'for this couple to',
#  'this couple to be',
#  'couple to be pretending',
#  'to be pretending .',
#  'be pretending . The',
#  'pretending . The boy',
#  '. The boy licked',
#  'The boy licked his',
#  'boy licked his dry',
#  'licked his dry lips',
#  'his dry lips .',
#  'dry lips . He',
#  'lips . He asked',
#  '. He asked ,',
#  'He asked , ``',
#  'asked , `` Could',
#  ', `` Could we',
#  '`` Could we have',
#  'Could we have a',
#  'we have a drink',
#  "have a drink ''",
#  "a drink '' ?",
#  "drink '' ? ?",
#  "'' ? ? Morgan",
#  '? ? Morgan jerked',
#  '? Morgan jerked his',
#  'Morgan jerked his head',
#  'jerked his head toward',
#  'his head toward the',
#  'head toward the front',
#  'toward the front door',
#  'the front door .',
#  'front door . ``',
#  'door . `` In',
#  '. `` In the',
#  '`` In the kitchen',
#  "In the kitchen ''",
#  "the kitchen '' ,",
#  "kitchen '' , he",
#  "'' , he said",
#  ', he said .',
#  'he said . Leaning',
#  'said . Leaning his',
#  '. Leaning his Winchester',
#  'Leaning his Winchester against',
#  'his Winchester against the',
#  'Winchester against the front',
#  'against the front of',
#  'the front of the',
#  'front of the house',
#  'of the house ,',
#  'the house , he',
#  'house , he walked',
#  ', he walked to',
#  'he walked to the',
#  'walked to the girl',
#  'to the girl .',
#  'the girl . ``',
#  'girl . `` Get',
#  '. `` Get up',
#  '`` Get up .',
#  "Get up . There's",
#  "up . There's water",
#  ". There's water in",
#  "There's water in the",
#  'water in the house',
#  "in the house ''",
#  "the house '' .",
#  "house '' . She",
#  "'' . She didn't",
#  ". She didn't move",
#  "She didn't move or",
#  "didn't move or say",
#  'move or say anything',
#  'or say anything .',
#  'say anything . Her',
#  'anything . Her eyes',
#  '. Her eyes were',
#  'Her eyes were glazed',
#  'eyes were glazed as',
#  'were glazed as if',
#  'glazed as if she',
#  "as if she didn't",
#  "if she didn't hear",
#  "she didn't hear or",
#  "didn't hear or even",
#  'hear or even see',
#  'or even see him',
#  'even see him .',
#  'see him . She',
#  'him . She had',
#  '. She had reached',
#  'She had reached a',
#  'had reached a point',
#  'reached a point at',
#  'a point at which',
#  'point at which she',
#  "at which she didn't",
#  "which she didn't even",
#  "she didn't even care",
#  "didn't even care how",
#  'even care how she',
#  'care how she looked',
#  'how she looked .',
#  'she looked . Her',
#  'looked . Her face',
#  '. Her face was',
#  'Her face was very',
#  'face was very thin',
#  'was very thin ,',
#  'very thin , and',
#  'thin , and burned',
#  ', and burned by',
#  'and burned by the',
#  'burned by the sun',
#  'by the sun until',
#  'the sun until much',
#  'sun until much of',
#  'until much of the',
#  'much of the skin',
#  'of the skin was',
#  'the skin was dead',
#  'skin was dead and',
#  'was dead and peeling',
#  'dead and peeling ,',
#  'and peeling , the',
#  'peeling , the new',
#  ', the new skin',
#  'the new skin under',
#  'new skin under it',
#  'skin under it red',
#  'under it red and',
#  'it red and angry',
#  'red and angry .',
#  'and angry . Her',
#  'angry . Her blond',
#  '. Her blond hair',
#  'Her blond hair was',
#  'blond hair was frowzy',
#  'hair was frowzy ,',
#  'was frowzy , her',
#  'frowzy , her dress',
#  ', her dress torn',
#  'her dress torn in',
#  'dress torn in several',
#  'torn in several places',
#  'in several places ,',
#  'several places , and',
#  'places , and her',
#  ', and her shoes',
#  'and her shoes were',
#  'her shoes were so',
#  'shoes were so completely',
#  'were so completely worn',
#  'so completely worn out',
#  'completely worn out that',
#  'worn out that they',
#  'out that they were',
#  'that they were practically',
#  'they were practically no',
#  'were practically no protection',
#  'practically no protection .',
#  'no protection . It',
#  'protection . It must',
#  '. It must have',
#  'It must have hurt',
#  'must have hurt her',
#  'have hurt her even',
#  'hurt her even to',
#  'her even to walk',
#  'even to walk ,',
#  'to walk , for',
#  'walk , for the',
#  ', for the sole',
#  'for the sole was',
#  'the sole was completely',
#  'sole was completely off',
#  'was completely off her',
#  'completely off her left',
#  'off her left foot',
#  'her left foot and',
#  'left foot and Morgan',
#  'foot and Morgan saw',
#  'and Morgan saw that',
#  'Morgan saw that it',
#  'saw that it was',
#  'that it was bruised',
#  'it was bruised and',
#  'was bruised and bleeding',
#  'bruised and bleeding .',
#  'and bleeding . He',
#  'bleeding . He picked',
#  '. He picked her',
#  'He picked her up',
#  'picked her up ,',
#  'her up , sliding',
#  'up , sliding one',
#  ', sliding one hand',
#  'sliding one hand under',
#  'one hand under her',
#  'hand under her shoulders',
#  'under her shoulders ,',
#  'her shoulders , the',
#  'shoulders , the other',
#  ', the other under',
#  'the other under her',
#  'other under her knees',
#  'under her knees ,',
#  'her knees , and',
#  'knees , and carried',
#  ', and carried her',
#  'and carried her into',
#  'carried her into the',
#  'her into the house',
#  'into the house .',
#  'the house . She',
#  'house . She was',
#  '. She was amazingly',
#  'She was amazingly light',
#  'was amazingly light ,',
#  'amazingly light , and',
#  'light , and so',
#  ', and so relaxed',
#  'and so relaxed in',
#  'so relaxed in his',
#  'relaxed in his arms',
#  'in his arms that',
#  'his arms that he',
#  "arms that he wasn't",
#  "that he wasn't even",
#  "he wasn't even sure",
#  "wasn't even sure she",
#  'even sure she was',
#  'sure she was conscious',
#  'she was conscious .',
#  'was conscious . Any',
#  'conscious . Any lingering',
#  '. Any lingering suspicion',
#  'Any lingering suspicion that',
#  'lingering suspicion that this',
#  'suspicion that this was',
#  'that this was a',
#  'this was a trick',
#  'was a trick Al',
#  'a trick Al Budd',
#  'trick Al Budd had',
#  'Al Budd had thought',
#  'Budd had thought up',
#  'had thought up was',
#  'thought up was dispelled',
#  'up was dispelled .',
#  'was dispelled . No',
#  'dispelled . No girl',
#  '. No girl would',
#  'No girl would go',
#  'girl would go this',
#  'would go this far',
#  'go this far to',
#  'this far to fool',
#  'far to fool a',
#  'to fool a man',
#  'fool a man so',
#  'a man so she',
#  'man so she could',
#  'so she could kill',
#  'she could kill him',
#  'could kill him .',
#  'kill him . Besides',
#  'him . Besides ,',
#  '. Besides , she',
#  'Besides , she had',
#  ', she had a',
#  'she had a sweet',
#  'had a sweet face',
#  'a sweet face that',
#  'sweet face that attracted',
#  'face that attracted him',
#  'that attracted him .',
#  'attracted him . He',
#  'him . He put',
#  '. He put her',
#  'He put her down',
#  'put her down on',
#  'her down on the',
#  'down on the couch',
#  'on the couch ,',
#  'the couch , and',
#  'couch , and going',
#  ', and going into',
#  'and going into the',
#  'going into the kitchen',
#  'into the kitchen ,',
#  'the kitchen , saw',
#  'kitchen , saw that',
#  ', saw that the',
#  'saw that the boy',
#  'that the boy had',
#  'the boy had dropped',
#  'boy had dropped into',
#  'had dropped into a',
#  'dropped into a chair',
#  'into a chair beside',
#  'a chair beside the',
#  'chair beside the table',
#  'beside the table .',
#  'the table . They',
#  'table . They looked',
#  '. They looked a',
#  'They looked a good',
#  'looked a good deal',
#  'a good deal alike',
#  'good deal alike ,',
#  'deal alike , Morgan',
#  'alike , Morgan thought',
#  ', Morgan thought .',
#  'Morgan thought . Both',
#  'thought . Both had',
#  '. Both had blonde',
#  'Both had blonde hair',
#  'had blonde hair and',
#  'blonde hair and blue',
#  'hair and blue eyes',
#  'and blue eyes ,',
#  'blue eyes , and',
#  'eyes , and there',
#  ', and there was',
#  'and there was even',
#  'there was even a',
#  'was even a faint',
#  'even a faint similarity',
#  'a faint similarity of',
#  'faint similarity of features',
#  'similarity of features .',
#  'of features . Morgan',
#  'features . Morgan filled',
#  '. Morgan filled the',
#  'Morgan filled the dipper',
#  'filled the dipper from',
#  'the dipper from the',
#  'dipper from the water',
#  'from the water bucket',
#  'the water bucket on',
#  'water bucket on the',
#  'bucket on the shelf',
#  'on the shelf ,',
#  'the shelf , went',
#  ...]

# %%
a = extract_ngrams(x, 3)
a[0]
# Out:
# 'Dan Morgan told'
